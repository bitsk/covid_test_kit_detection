# %%
# !aipubuild -v
# Out:
# /home/bits/anaconda3/envs/aipu/bin/aipubuild	version: 4.1.274
# Parser   	version: 1.2.274
# Optimizer	version: 1.0
# Core Lib 	version: 4.1.274 	git commit: 00806cde2a4527a48979c69f436bb19a20abd408
# aipurun  	version: 4.1.274
# aipugb   	version: 4.1.274
#
# Dataset plugins version:
# NumpyDataset            	version:0.01
# RandomDataset           	version:0.01
# VOCDataset              	version:0.01
# AiShellDataset          	version:0.01
# MTCNNDataset            	version:0.01
# LibriSpeechDataset      	version:0.01
# NumpyDatasetMutiInput   	version:0.01
# GeneralDictDataset      	version:0.01
# IWSLTDataset            	version:0.01
# FasterrcnnVocDataset    	version:0.01
# CocoDataset             	version:0.01
#
# Metric plugins version:
# CosDistanceMetric       	version:0.01
# MaskRcnnCOCOmAPMetric   	version:0.01
# mIoUMetric              	version:0.01
# TopKMetric              	version:0.01
# VOCmAPMetric            	version:0.01
# FasterRcnnCaffemAPMetric	version:0.01
# ...

# %%
onnx_model_path = "../onnx/scrfd_x00m_bnkps_fast_covid-kit_resnet_shape640x640.onnx"

# %%
# !aipubuild aipu_build_scrfd.cfg
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# [I] Parsing model....
# [I] [Parser]: Begin to parse onnx model scrfd_res...
# [W] [Parser]: the output name score_8 is not a node but a tensor. However, we will use the node Sigmoid_99 as output node.
# [W] [Parser]: the output name score_16 is not a node but a tensor. However, we will use the node Sigmoid_122 as output node.
# [W] [Parser]: the output name score_32 is not a node but a tensor. However, we will use the node Sigmoid_145 as output node.
# [W] [Parser]: the output name bbox_8 is not a node but a tensor. However, we will use the node Reshape_103 as output node.
# ...

# %%
# !aipubuild aipu_build_scrfd.cfg
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# [I] Parsing model....
# [I] [Parser]: Begin to parse onnx model scrfd_res...
# 2022-05-24 17:41:02.604375: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-05-24 17:41:02.620623: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2904000000 Hz
# 2022-05-24 17:41:02.622587: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558f6cd64ef0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %%
# !aipubuild aipu_build_scrfd.cfg
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# [I] Parsing model....
# [I] [Parser]: Begin to parse onnx model scrfd_res...
# 2022-05-24 21:36:02.331276: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-05-24 21:36:02.344627: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2904000000 Hz
# 2022-05-24 21:36:02.346216: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5607f19aced0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...
